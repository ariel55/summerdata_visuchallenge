# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# !pip install folium
import folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.6/dist-packages (0.8.3)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from folium) (0.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from folium) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from folium) (1.15.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from folium) (2.11.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from folium) (2.23.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->folium) (1.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->folium) (3.0.4)

# %%
oportunidades = pd.read_csv("/content/drive/My Drive/Datos/Entrenamieto_ECI_2020.csv")

# %%
#Todos están convertidos a USD, entonces esta columna la puedo sacar y documento que directamente ASP_(converted) es todo en USD
oportunidades['ASP_(converted)_Currency'].value_counts()
# Out:
# USD    16947
# Name: ASP_(converted)_Currency, dtype: int64

# %%
#elimino columna
oportunidades.drop(columns= 'ASP_(converted)_Currency')
# Out:
#           ID    Region  ...        Stage       Prod_Category_A
# 0      27761      EMEA  ...  Closed Lost  Prod_Category_A_None
# 1      27760      EMEA  ...   Closed Won  Prod_Category_A_None
# 2      27446  Americas  ...   Closed Won  Prod_Category_A_None
# 3      16808  Americas  ...  Closed Lost  Prod_Category_A_None
# 4      16805  Americas  ...  Closed Lost  Prod_Category_A_None
# ...      ...       ...  ...          ...                   ...
# 16942   8781      EMEA  ...   Closed Won  Prod_Category_A_None
# 16943   8786      EMEA  ...   Closed Won  Prod_Category_A_None
# 16944   8792      EMEA  ...   Closed Won  Prod_Category_A_None
# 16945  28561  Americas  ...  Closed Lost  Prod_Category_A_None
# 16946  28318  Americas  ...  Closed Lost  Prod_Category_A_None
#
# [16947 rows x 51 columns]

# %%
oportunidades.loc[:, ['ASP_Currency', 'ASP', 'ASP_(converted)', 'Total_Taxable_Amount_Currency', 'Total_Taxable_Amount']]
# Out:
#       ASP_Currency     ASP  ...  Total_Taxable_Amount_Currency Total_Taxable_Amount
# 0              EUR  0.5200  ...                            EUR            5272800.0
# 1              EUR  0.5300  ...                            EUR              48230.0
# 2              USD  0.4800  ...                            USD              83865.6
# 3              USD  0.5300  ...                            USD            7421881.5
# 4              USD  0.5300  ...                            USD           13357192.5
# ...            ...     ...  ...                            ...                  ...
# 16942          EUR  0.5200  ...                            EUR             299715.0
# 16943          EUR  0.5200  ...                            EUR             299715.0
# 16944          EUR  0.5200  ...                            EUR             299715.0
# 16945          USD  0.6375  ...                            USD                  0.0
# 16946          USD  0.6400  ...                            USD                  0.0
#
# [16947 rows x 5 columns]

# %%
oportunidades.head()
# Out:
#       ID    Region  ...        Stage       Prod_Category_A
# 0  27761      EMEA  ...  Closed Lost  Prod_Category_A_None
# 1  27760      EMEA  ...   Closed Won  Prod_Category_A_None
# 2  27446  Americas  ...   Closed Won  Prod_Category_A_None
# 3  16808  Americas  ...  Closed Lost  Prod_Category_A_None
# 4  16805  Americas  ...  Closed Lost  Prod_Category_A_None
#
# [5 rows x 52 columns]

# %%
oportunidades['Account_Created_Date'] = pd.to_datetime(oportunidades['Account_Created_Date'])
oportunidades['Opportunity_Created_Date'] = pd.to_datetime(oportunidades['Opportunity_Created_Date'])
oportunidades['Quote_Expiry_Date'] = pd.to_datetime(oportunidades['Quote_Expiry_Date'])
oportunidades['Last_Modified_Date'] = pd.to_datetime(oportunidades['Last_Modified_Date'])
oportunidades['Planned_Delivery_Start_Date'] = pd.to_datetime(oportunidades['Planned_Delivery_Start_Date'])
oportunidades['Planned_Delivery_End_Date'] = pd.to_datetime(oportunidades['Planned_Delivery_End_Date'])
#oportunidades['Month'] = pd.to_datetime(oportunidades['Month'])
#oportunidades['Delivery_Year'] = pd.to_datetime(oportunidades['Delivery_Year'])


#Qué hacer con los None?
#oportunidades['Price'] = pd.to_numeric(oportunidades['Price'])

oportunidades['ASP'] = pd.to_numeric(oportunidades['ASP'])
oportunidades['ASP_(converted)'] = pd.to_numeric(oportunidades['ASP_(converted)'])
oportunidades['Total_Amount'] = pd.to_numeric(oportunidades['Total_Amount'])
oportunidades['Total_Taxable_Amount'] = pd.to_numeric(oportunidades['Total_Taxable_Amount'])

#Que hacer con los None?
#oportunidades['Sales_Contract_No'] = pd.to_numeric(oportunidades['Sales_Contract_No'])

# %%
oportunidades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16947 entries, 0 to 16946
# Data columns (total 52 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  16947 non-null  int64
#  1   Region                              16947 non-null  object
#  2   Territory                           16947 non-null  object
#  3   Pricing, Delivery_Terms_Quote_Appr  16947 non-null  int64
#  4   Pricing, Delivery_Terms_Approved    16947 non-null  int64
#  5   Bureaucratic_Code_0_Approval        16947 non-null  int64
#  6   Bureaucratic_Code_0_Approved        16947 non-null  int64
#  7   Submitted_for_Approval              16947 non-null  int64
#  8   Bureaucratic_Code                   16947 non-null  object
#  9   Account_Created_Date                16947 non-null  datetime64[ns]
#  10  Source                              16947 non-null  object
#  11  Billing_Country                     16947 non-null  object
#  12  Account_Name                        16947 non-null  object
#  13  Opportunity_Name                    16947 non-null  object
#  14  Opportunity_ID                      16947 non-null  int64
#  15  Sales_Contract_No                   16947 non-null  object
#  16  Account_Owner                       16947 non-null  object
#  17  Opportunity_Owner                   16947 non-null  object
#  18  Account_Type                        16947 non-null  object
#  19  Opportunity_Type                    16947 non-null  object
#  20  Quote_Type                          16947 non-null  object
#  21  Delivery_Terms                      16947 non-null  object
#  22  Opportunity_Created_Date            16947 non-null  datetime64[ns]
#  23  Brand                               16947 non-null  object
#  24  Product_Type                        16947 non-null  object
#  25  Size                                16947 non-null  object
#  26  Product_Category_B                  16947 non-null  object
#  27  Price                               16947 non-null  object
#  28  Currency                            16947 non-null  object
#  29  Last_Activity                       16947 non-null  object
#  30  Quote_Expiry_Date                   12322 non-null  datetime64[ns]
#  31  Last_Modified_Date                  16947 non-null  datetime64[ns]
#  32  Last_Modified_By                    16947 non-null  object
#  33  Product_Family                      16947 non-null  object
#  34  Product_Name                        16947 non-null  object
#  35  ASP_Currency                        16947 non-null  object
#  36  ASP                                 13738 non-null  float64
#  37  ASP_(converted)_Currency            16947 non-null  object
#  38  ASP_(converted)                     13738 non-null  float64
#  39  Planned_Delivery_Start_Date         16947 non-null  datetime64[ns]
#  40  Planned_Delivery_End_Date           16872 non-null  datetime64[ns]
#  41  Month                               16947 non-null  object
#  42  Delivery_Quarter                    16947 non-null  object
#  43  Delivery_Year                       16947 non-null  int64
#  44  Actual_Delivery_Date                16947 non-null  object
#  45  TRF                                 16947 non-null  int64
#  46  Total_Amount_Currency               16947 non-null  object
#  47  Total_Amount                        16888 non-null  float64
#  48  Total_Taxable_Amount_Currency       16947 non-null  object
#  49  Total_Taxable_Amount                16947 non-null  float64
#  50  Stage                               16947 non-null  object
#  51  Prod_Category_A                     16947 non-null  object
# dtypes: datetime64[ns](6), float64(4), int64(9), object(33)
# memory usage: 6.7+ MB

# %%
len(oportunidades)
# Out:
# 16947

# %%
oportunidades.count()
# Out:
# ID                                    16947
# Region                                16947
# Territory                             16947
# Pricing, Delivery_Terms_Quote_Appr    16947
# Pricing, Delivery_Terms_Approved      16947
# Bureaucratic_Code_0_Approval          16947
# Bureaucratic_Code_0_Approved          16947
# Submitted_for_Approval                16947
# Bureaucratic_Code                     16947
# Account_Created_Date                  16947
# Source                                16947
# Billing_Country                       16947
# Account_Name                          16947
# Opportunity_Name                      16947
# Opportunity_ID                        16947
# Sales_Contract_No                     16947
# Account_Owner                         16947
# Opportunity_Owner                     16947
# Account_Type                          16947
# Opportunity_Type                      16947
# Quote_Type                            16947
# Delivery_Terms                        16947
# Opportunity_Created_Date              16947
# Brand                                 16947
# Product_Type                          16947
# Size                                  16947
# Product_Category_B                    16947
# Price                                 16947
# Currency                              16947
# Last_Activity                         16947
# Quote_Expiry_Date                     12322
# Last_Modified_Date                    16947
# Last_Modified_By                      16947
# Product_Family                        16947
# Product_Name                          16947
# ASP_Currency                          16947
# ASP                                   13738
# ASP_(converted)_Currency              16947
# ASP_(converted)                       13738
# Planned_Delivery_Start_Date           16947
# Planned_Delivery_End_Date             16872
# Month                                 16947
# Delivery_Quarter                      16947
# Delivery_Year                         16947
# Actual_Delivery_Date                  16947
# TRF                                   16947
# Total_Amount_Currency                 16947
# Total_Amount                          16888
# Total_Taxable_Amount_Currency         16947
# Total_Taxable_Amount                  16947
# Stage                                 16947
# Prod_Category_A                       16947
# dtype: int64

# %%
#veo que todosl los valores de Last_Activity son nulos
oportunidades['Last_Activity'].value_counts()
# Out:
# NaT    16947
# Name: Last_Activity, dtype: int64

# %%
#elimino la columna
oportunidades.drop(columns='Last_Activity', inplace=True)

# %%
#veo que todos los valores de Actual_Delivery_Date son nulos
oportunidades['Actual_Delivery_Date'].value_counts()
# Out:
# NaT    16947
# Name: Actual_Delivery_Date, dtype: int64

# %%
#elimino la columna
oportunidades.drop(columns='Actual_Delivery_Date', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-21030a010779> in <module>()
#       1 #elimino la columna
# ----> 2 oportunidades.drop(columns='Actual_Delivery_Date', inplace=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5282         if mask.any():
#    5283             if errors != "ignore":
# -> 5284                 raise KeyError(f"{labels[mask]} not found in axis")
#    5285             indexer = indexer[~mask]
#    5286         return self.delete(indexer)
#
# KeyError: "['Actual_Delivery_Date'] not found in axis"

# %%
oportunidades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16947 entries, 0 to 16946
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  16947 non-null  int64
#  1   Region                              16947 non-null  object
#  2   Territory                           16947 non-null  object
#  3   Pricing, Delivery_Terms_Quote_Appr  16947 non-null  int64
#  4   Pricing, Delivery_Terms_Approved    16947 non-null  int64
#  5   Bureaucratic_Code_0_Approval        16947 non-null  int64
#  6   Bureaucratic_Code_0_Approved        16947 non-null  int64
#  7   Submitted_for_Approval              16947 non-null  int64
#  8   Bureaucratic_Code                   16947 non-null  object
#  9   Account_Created_Date                16947 non-null  datetime64[ns]
#  10  Source                              16947 non-null  object
#  11  Billing_Country                     16947 non-null  object
#  12  Account_Name                        16947 non-null  object
#  13  Opportunity_Name                    16947 non-null  object
#  14  Opportunity_ID                      16947 non-null  int64
#  15  Sales_Contract_No                   16947 non-null  object
#  16  Account_Owner                       16947 non-null  object
#  17  Opportunity_Owner                   16947 non-null  object
#  18  Account_Type                        16947 non-null  object
#  19  Opportunity_Type                    16947 non-null  object
#  20  Quote_Type                          16947 non-null  object
#  21  Delivery_Terms                      16947 non-null  object
#  22  Opportunity_Created_Date            16947 non-null  datetime64[ns]
#  23  Brand                               16947 non-null  object
#  24  Product_Type                        16947 non-null  object
#  25  Size                                16947 non-null  object
#  26  Product_Category_B                  16947 non-null  object
#  27  Price                               16947 non-null  object
#  28  Currency                            16947 non-null  object
#  29  Quote_Expiry_Date                   12322 non-null  datetime64[ns]
#  30  Last_Modified_Date                  16947 non-null  datetime64[ns]
#  31  Last_Modified_By                    16947 non-null  object
#  32  Product_Family                      16947 non-null  object
#  33  Product_Name                        16947 non-null  object
#  34  ASP_Currency                        16947 non-null  object
#  35  ASP                                 13738 non-null  float64
#  36  ASP_(converted)_Currency            16947 non-null  object
#  37  ASP_(converted)                     13738 non-null  float64
#  38  Planned_Delivery_Start_Date         16947 non-null  datetime64[ns]
#  39  Planned_Delivery_End_Date           16872 non-null  datetime64[ns]
#  40  Month                               16947 non-null  object
#  41  Delivery_Quarter                    16947 non-null  object
#  42  Delivery_Year                       16947 non-null  int64
#  43  TRF                                 16947 non-null  int64
#  44  Total_Amount_Currency               16947 non-null  object
#  45  Total_Amount                        16888 non-null  float64
#  46  Total_Taxable_Amount_Currency       16947 non-null  object
#  47  Total_Taxable_Amount                16947 non-null  float64
#  48  Stage                               16947 non-null  object
#  49  Prod_Category_A                     16947 non-null  object
# dtypes: datetime64[ns](6), float64(4), int64(9), object(31)
# memory usage: 6.5+ MB

# %%
oportunidades.count()
# Out:
# ID                                    16947
# Region                                16947
# Territory                             16947
# Pricing, Delivery_Terms_Quote_Appr    16947
# Pricing, Delivery_Terms_Approved      16947
# Bureaucratic_Code_0_Approval          16947
# Bureaucratic_Code_0_Approved          16947
# Submitted_for_Approval                16947
# Bureaucratic_Code                     16947
# Account_Created_Date                  16947
# Source                                16947
# Billing_Country                       16947
# Account_Name                          16947
# Opportunity_Name                      16947
# Opportunity_ID                        16947
# Sales_Contract_No                     16947
# Account_Owner                         16947
# Opportunity_Owner                     16947
# Account_Type                          16947
# Opportunity_Type                      16947
# Quote_Type                            16947
# Delivery_Terms                        16947
# Opportunity_Created_Date              16947
# Brand                                 16947
# Product_Type                          16947
# Size                                  16947
# Product_Category_B                    16947
# Price                                 16947
# Currency                              16947
# Quote_Expiry_Date                     12322
# Last_Modified_Date                    16947
# Last_Modified_By                      16947
# Product_Family                        16947
# Product_Name                          16947
# ASP_Currency                          16947
# ASP                                   13738
# ASP_(converted)_Currency              16947
# ASP_(converted)                       13738
# Planned_Delivery_Start_Date           16947
# Planned_Delivery_End_Date             16872
# Month                                 16947
# Delivery_Quarter                      16947
# Delivery_Year                         16947
# TRF                                   16947
# Total_Amount_Currency                 16947
# Total_Amount                          16888
# Total_Taxable_Amount_Currency         16947
# Total_Taxable_Amount                  16947
# Stage                                 16947
# Prod_Category_A                       16947
# dtype: int64

# %%
#columna Quote_Expiry_Date tiene muchos valores NaT

# %%
oportunidades['Quote_Expiry_Date'].value_counts()
# Out:
# 2017-06-30    436
# 2017-03-31    363
# 2017-09-30    225
# 2016-12-31    200
# 2017-10-31    171
#              ...
# 2018-12-20      1
# 2016-03-28      1
# 2016-01-04      1
# 2016-06-19      1
# 2016-10-23      1
# Name: Quote_Expiry_Date, Length: 1002, dtype: int64

# %%
oportunidades['Quote_Type'].value_counts()
# Out:
# Non Binding    16777
# Binding          170
# Name: Quote_Type, dtype: int64

# %%
oportunidades['ASP'].value_counts()
# Out:
# 0.38000    801
# 0.40000    712
# 0.36000    564
# 0.42000    510
# 0.39000    465
#           ...
# 0.34730      1
# 0.27400      1
# 0.25300      1
# 0.45789      1
# 0.24400      1
# Name: ASP, Length: 301, dtype: int64

# %%
oportunidades['ASP_(converted)'].value_counts()
# Out:
# 0.38000    570
# 0.40000    497
# 0.36000    326
# 0.39000    325
# 0.00000    300
#           ...
# 0.32365      1
# 0.67868      1
# 0.43820      1
# 0.47300      1
# 0.30567      1
# Name: ASP_(converted), Length: 441, dtype: int64

# %%
oportunidades['Total_Amount'].value_counts()
# Out:
# 6200.0        513
# 4400.0        461
# 18000.0       353
# 140000.0      272
# 1600.0        204
#              ...
# 193600.0        1
# 4972.8          1
# 8001840.0       1
# 12333750.0      1
# 11960.0         1
# Name: Total_Amount, Length: 8872, dtype: int64

# %%
oportunidades.drop(columns='Submitted_for_Approval', inplace=True)

# %%
oportunidades.drop(columns='ASP_(converted)_Currency', inplace=True)

# %%
oportunidades.drop(columns='Prod_Category_A', inplace=True)

# %%
#cantidad de TRF requeridas por país
cant_TRF_por_pais = oportunidades.groupby(['Billing_Country']).agg({'TRF':'sum'}).reset_index()
cant_TRF_por_pais
# Out:
#          Billing_Country    TRF
# 0                Albania      4
# 1              Argentina      1
# 2                Armenia     55
# 3              Australia   5577
# 4                Austria     43
# ..                   ...    ...
# 75                Turkey    158
# 76  United Arab Emirates    647
# 77        United Kingdom    559
# 78         United States  15853
# 79              Viet Nam    411
#
# [80 rows x 2 columns]

# %%
es_Closed_Won = (oportunidades['Stage'] == 'Closed Won')

# %%
#por pais cuántos closed won tengo
op_closed_won = oportunidades[es_Closed_Won].groupby(['Billing_Country']).agg({'Stage': lambda x: x.value_counts()}).reset_index()
col_op_closed_won = {'Stage':'Quantity_Closed_Won'}
op_closed_won.rename(columns=col_op_closed_won, inplace= True)
op_closed_won.head()
# Out:
#   Billing_Country  Quantity_Closed_Won
# 0       Australia                  695
# 1         Austria                  122
# 2         Bahrain                    1
# 3         Belgium                  119
# 4        Bulgaria                    1

# %%
codigo_0_aprobado = oportunidades['Bureaucratic_Code_0_Approved'] == 1

# %%
codigo_0_closed_won = oportunidades[(es_Closed_Won & codigo_0_aprobado)].groupby(['Billing_Country']).agg({'Stage': lambda x: x.value_counts()}).reset_index()
col_codigo_0_closed_won = {'Stage':'Quantity_Closed_Won'}
codigo_0_closed_won.rename(columns=col_codigo_0_closed_won, inplace= True)
codigo_0_closed_won.head()
# Out:
#   Billing_Country  Quantity_Closed_Won
# 0       Australia                  324
# 1         Austria                   19
# 2         Bahrain                    1
# 3         Belgium                   40
# 4        Cambodia                    1

# %%
codigo_0_closed_won.nlargest(25, columns='Quantity_Closed_Won')
# Out:
#                            Billing_Country  Quantity_Closed_Won
# 14                                   Japan                  599
# 42                           United States                  487
# 9                                  Germany                  346
# 0                                Australia                  324
# 6                                    China                  176
# 11                                   India                  145
# 31                               Singapore                  133
# 33                                   Spain                   85
# 21                             Netherlands                   82
# 41                          United Kingdom                   46
# 25                             Philippines                   43
# 13                                   Italy                   42
# 3                                  Belgium                   40
# 38                                Thailand                   37
# 8                                   France                   36
# 15                                  Jordan                   32
# 34                               Sri Lanka                   30
# 1                                  Austria                   19
# 19                              Luxembourg                   17
# 12                               Indonesia                   14
# 27                                Portugal                   11
# 22                             New Zealand                    9
# 32                            South Africa                    8
# 23                                  Norway                    6
# 16  Korea, Democratic People's Republic of                    5

# %%
#cantidad de dinero gastado en cada oportunidad
oportunidades.groupby('Opportunity_Name').agg({'Total_Taxable_Amount': 'sum'}).reset_index()
# Out:
#             Opportunity_Name  Total_Taxable_Amount
# 0         Opportunity_Name_0          2.446080e+07
# 1         Opportunity_Name_1          1.535170e+07
# 2       Opportunity_Name_100          5.437800e+05
# 3      Opportunity_Name_1000          1.421420e+08
# 4     Opportunity_Name_10000          0.000000e+00
# ...                      ...                   ...
# 9836   Opportunity_Name_9992          0.000000e+00
# 9837   Opportunity_Name_9995          2.086980e+06
# 9838   Opportunity_Name_9996          7.902469e+05
# 9839   Opportunity_Name_9997          3.799810e+06
# 9840   Opportunity_Name_9998          7.252200e+05
#
# [9841 rows x 2 columns]

# %%
#inversiones de cada país
oportunidades.groupby(['Billing_Country']).agg({'Total_Taxable_Amount': 'sum'}).reset_index()
# Out:
#          Billing_Country  Total_Taxable_Amount
# 0                Albania          1.468530e+06
# 1              Argentina          2.356200e+05
# 2                Armenia          3.878873e+07
# 3              Australia          4.650773e+09
# 4                Austria          5.249600e+07
# ..                   ...                   ...
# 75                Turkey          1.634101e+08
# 76  United Arab Emirates          1.573925e+08
# 77        United Kingdom          5.070478e+08
# 78         United States          1.561297e+10
# 79              Viet Nam          1.580962e+08
#
# [80 rows x 2 columns]

# %%
#ninguna oportunidad fue enviada para aprobación
oportunidades['Submitted_for_Approval'].value_counts()
# Out:
# 0    16947
# Name: Submitted_for_Approval, dtype: int64

# %%
#de acuerdo al código burocrático cuántas necesitan aprobación especial y cuántas son aprobadas
#se puede ver que las que requieren código 5 no son aprobadas nunca
aprobacion_por_codigo = oportunidades.groupby('Bureaucratic_Code').agg({'Pricing, Delivery_Terms_Quote_Appr':'sum', 'Pricing, Delivery_Terms_Approved': 'sum'}).reset_index()
col_aprobacion_por_codigo = {'Pricing, Delivery_Terms_Quote_Appr':'Quantity_Need_Pricing_Delivery_Appr', 'Pricing, Delivery_Terms_Approved':'Quantity_Pricing_Delivery_Approved'}
aprobacion_por_codigo.rename(columns=col_aprobacion_por_codigo, inplace= True)
aprobacion_por_codigo.head()
# Out:
#      Bureaucratic_Code  ...  Quantity_Pricing_Delivery_Approved
# 0  Bureaucratic_Code_0  ...                                  42
# 1  Bureaucratic_Code_1  ...                                 130
# 2  Bureaucratic_Code_2  ...                                 234
# 3  Bureaucratic_Code_3  ...                                   1
# 4  Bureaucratic_Code_4  ...                                9482
#
# [5 rows x 3 columns]

# %%
closed_won_por_codigo = oportunidades[es_Closed_Won].groupby('Bureaucratic_Code').agg({'Stage': lambda x: x.value_counts()}).reset_index()
col_rename_closed_won_por_codigo = {'Stage': 'Quantity_Closed_Won'}
closed_won_por_codigo.rename(columns = col_rename_closed_won_por_codigo, inplace=True)
closed_won_por_codigo
# Out:
#      Bureaucratic_Code  Quantity_Closed_Won
# 0  Bureaucratic_Code_0                   51
# 1  Bureaucratic_Code_1                  102
# 2  Bureaucratic_Code_2                  114
# 3  Bureaucratic_Code_3                    1
# 4  Bureaucratic_Code_4                 8253
# 5  Bureaucratic_Code_5                 1011
# 6  Bureaucratic_Code_6                    1

# %%
#por pais, cantidad de aprobacion de codigo 0 que necesitan y cuantos son aprobados.
codigo_0 = oportunidades.groupby('Billing_Country').agg({'Bureaucratic_Code_0_Approval':'sum', 'Bureaucratic_Code_0_Approved':'sum'}).reset_index()
col_codigo_0 = {'Bureaucratic_Code_0_Approval':'Quantity_Need_Code_0_Approval', 'Bureaucratic_Code_0_Approved':'Quantity_Code_0_Approved'}
codigo_0.rename(columns=col_codigo_0)
# Out:
#          Billing_Country  ...  Quantity_Code_0_Approved
# 0                Albania  ...                         0
# 1              Argentina  ...                         0
# 2                Armenia  ...                         2
# 3              Australia  ...                       588
# 4                Austria  ...                        30
# ..                   ...  ...                       ...
# 75                Turkey  ...                        12
# 76  United Arab Emirates  ...                        25
# 77        United Kingdom  ...                       127
# 78         United States  ...                      1298
# 79              Viet Nam  ...                         6
#
# [80 rows x 3 columns]

# %%
#para cada país veo la cantidad de cada tipo de 'Stage' que hay. Me sirve para ver qué países llegan más a una negociación o a ganar una venta
group_by_country_and_stage = oportunidades.groupby(['Billing_Country', 'Stage']).agg({'Stage': lambda x: x.value_counts()})
columns_new = {'Stage':'Quantity_By_Stage'}
group_by_country_and_stage.rename(columns=columns_new, inplace=True)
group_by_country_and_stage.reset_index()
# Out:
#     Billing_Country        Stage  Quantity_By_Stage
# 0           Albania  Closed Lost                  2
# 1         Argentina  Closed Lost                  1
# 2           Armenia  Closed Lost                  2
# 3         Australia  Closed Lost                470
# 4         Australia   Closed Won                695
# ..              ...          ...                ...
# 142   United States   Closed Won               1755
# 143   United States  Negotiation                  8
# 144   United States     Proposal                  4
# 145        Viet Nam  Closed Lost                 21
# 146        Viet Nam   Closed Won                 16
#
# [147 rows x 3 columns]

# %%
oportunidades.groupby(['Billing_Country']).agg({'Total_Taxable_Amount': 'sum'}).reset_index()
# Out:
#          Billing_Country  Total_Taxable_Amount
# 0                Albania          1.468530e+06
# 1              Argentina          2.356200e+05
# 2                Armenia          3.878873e+07
# 3              Australia          4.650773e+09
# 4                Austria          5.249600e+07
# ..                   ...                   ...
# 75                Turkey          1.634101e+08
# 76  United Arab Emirates          1.573925e+08
# 77        United Kingdom          5.070478e+08
# 78         United States          1.561297e+10
# 79              Viet Nam          1.580962e+08
#
# [80 rows x 2 columns]

# %%
oportunidades['Stage'].value_counts()
# Out:
# Closed Won       9533
# Closed Lost      7350
# Proposal           35
# Negotiation        18
# Qualification      11
# Name: Stage, dtype: int64

# %%
op_sin_pais_none = oportunidades.loc[oportunidades['Billing_Country'] != "None", :]
op_sin_pais_none
# Out:
#           ID    Region  ...        Stage       Prod_Category_A
# 0      27761      EMEA  ...  Closed Lost  Prod_Category_A_None
# 1      27760      EMEA  ...   Closed Won  Prod_Category_A_None
# 2      27446  Americas  ...   Closed Won  Prod_Category_A_None
# 3      16808  Americas  ...  Closed Lost  Prod_Category_A_None
# 4      16805  Americas  ...  Closed Lost  Prod_Category_A_None
# ...      ...       ...  ...          ...                   ...
# 16942   8781      EMEA  ...   Closed Won  Prod_Category_A_None
# 16943   8786      EMEA  ...   Closed Won  Prod_Category_A_None
# 16944   8792      EMEA  ...   Closed Won  Prod_Category_A_None
# 16945  28561  Americas  ...  Closed Lost  Prod_Category_A_None
# 16946  28318  Americas  ...  Closed Lost  Prod_Category_A_None
#
# [16920 rows x 50 columns]

# %%
op_sin_pais_none['Billing_Country'].value_counts()
# Out:
# Japan            4879
# United States    3802
# Germany          1979
# Australia        1169
# India             672
#                  ...
# Oman                1
# Colombia            1
# Ecuador             1
# Chile               1
# Belize              1
# Name: Billing_Country, Length: 79, dtype: int64

# %%
lista_paises = pd.DataFrame({'Billing_Country': op_sin_pais_none['Billing_Country'].unique()})
lista_paises
# Out:
#    Billing_Country
# 0      Netherlands
# 1    United States
# 2            Japan
# 3            India
# 4            Italy
# ..             ...
# 74         Bahrain
# 75         Estonia
# 76            Oman
# 77         Belarus
# 78            Peru
#
# [79 rows x 1 columns]

# %%
op_closed_won.nlargest(15, columns = 'Quantity_Closed_Won')
# Out:
#    Billing_Country  Quantity_Closed_Won
# 2            Japan               3323.0
# 1    United States               1755.0
# 5          Germany               1122.0
# 23       Australia                695.0
# 15       Singapore                318.0
# 0      Netherlands                315.0
# 3            India                284.0
# 29           China                203.0
# 13           Spain                192.0
# 4            Italy                152.0
# 6   United Kingdom                127.0
# 10         Austria                122.0
# 12         Belgium                119.0
# 14          France                111.0
# 19        Thailand                 90.0

# %%
len(op_sin_pais_none['Billing_Country'].unique())
# Out:
# 79

# %%
codigo_0 = codigo_0.loc[codigo_0['Billing_Country'] != "None", :]
codigo_0
# Out:
#          Billing_Country  ...  Bureaucratic_Code_0_Approved
# 0                Albania  ...                             0
# 1              Argentina  ...                             0
# 2                Armenia  ...                             2
# 3              Australia  ...                           588
# 4                Austria  ...                            30
# ..                   ...  ...                           ...
# 75                Turkey  ...                            12
# 76  United Arab Emirates  ...                            25
# 77        United Kingdom  ...                           127
# 78         United States  ...                          1298
# 79              Viet Nam  ...                             6
#
# [79 rows x 3 columns]

# %%
len(codigo_0)
# Out:
# 79

# %%
op_para_grafico = codigo_0.merge(codigo_0_closed_won, how = 'right', left_on = 'Billing_Country', right_on='Billing_Country')

# %%
op_closed_won['Quantity_Closed_Won'] = pd.to_numeric(op_closed_won['Quantity_Closed_Won'])

# %%
len(codigo_0['Bureaucratic_Code_0_Approval'])
# Out:
# 79

# %%
len(op_closed_won['Stage'])
# Out:
# 49

# %%
len(codigo_0['Bureaucratic_Code_0_Approved'])
# Out:
# 79

# %%
oportunidades_grafico = op_para_grafico

# %%
op_para_grafico = op_para_grafico.nlargest(15, columns='Quantity_Closed_Won')

# %%
op_para_grafico
# Out:
#    Billing_Country  ...  Quantity_Closed_Won
# 17           Japan  ...                 3323
# 47   United States  ...                 1755
# 12         Germany  ...                 1122
# 0        Australia  ...                  695
# 36       Singapore  ...                  318
# 26     Netherlands  ...                  315
# 14           India  ...                  284
# 7            China  ...                  203
# 38           Spain  ...                  192
# 16           Italy  ...                  152
# 46  United Kingdom  ...                  127
# 1          Austria  ...                  122
# 3          Belgium  ...                  119
# 11          France  ...                  111
# 43        Thailand  ...                   90
#
# [15 rows x 4 columns]

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd

# este grafico muestra las negociaciones exitosas solo para quellas oportunidades que su codigo cero fue aprobado, asi lo puedo comparar con las cantidades
#de codigo 0 aprobado y que necesitan aprobación
plt.figure(figsize=(50,20))
# y-axis in bold
rc('font', weight='bold')
 
# Values of each group
bars1 = op_para_grafico['Bureaucratic_Code_0_Approval']
bars2 = op_para_grafico['Bureaucratic_Code_0_Approved']
bars3 = op_para_grafico['Quantity_Closed_Won']
 
# Heights of bars1 + bars2
bars = np.add(0, bars3).tolist()
 
# The position of the bars on the x-axis
r = op_para_grafico['Billing_Country'].unique()
#r = [0,1,2,3,4,5]
 
# Names of group and bar width
#names = ['A','B','C','D','E']
barWidth = 1
 
# Create brown bars
plt.bar(r, bars1, color='#7f6d5f', edgecolor='white', width=barWidth, label = 'Necesitan aprobación de código 0')
# Create green bars (middle), on top of the firs ones
plt.bar(r, bars2, color='#557f2d',bottom=bars1, edgecolor='white', width=barWidth, label = 'Se aprobó el código 0')
# Create green bars (top)
plt.bar(r, bars3, color='#2d7f5e',bottom=bars1+bars2, edgecolor='white', width=barWidth, label = 'Negociaciones exitosas')


# Custom X axis
plt.xticks(r, op_para_grafico['Billing_Country'].unique(), fontweight='bold', rotation=90, fontsize = 25)
plt.yticks(fontsize = 25)
plt.legend(loc="upper right", fontsize = 35)
plt.title("15 países que aprobaron oportunidades de código 0 con mayor cantidad de negociaciones exitosas", fontsize = 50)
plt.ylabel("Cantidades por país", fontsize = 30)
# Show graphic
plt.show()

# %%
cant_TRF_por_pais.head()
# Out:
#   Billing_Country   TRF
# 0         Albania     4
# 1       Argentina     1
# 2         Armenia    55
# 3       Australia  5577
# 4         Austria    43

# %%
cant_TRF_por_pais = cant_TRF_por_pais.loc[cant_TRF_por_pais['Billing_Country'] != "None", :]

# %%
len(cant_TRF_por_pais)
# Out:
# 79

# %%
len(op_closed_won)
# Out:
# 49

# %%
op_closed_won = op_closed_won.merge(lista_paises, how='right', right_on='Billing_Country', left_on= 'Billing_Country').fillna(0)
op_closed_won
# Out:
#    Billing_Country  Quantity_Closed_Won
# 0      Netherlands                315.0
# 1    United States               1755.0
# 2            Japan               3323.0
# 3            India                284.0
# 4            Italy                152.0
# ..             ...                  ...
# 74         Bahrain                  1.0
# 75         Estonia                  1.0
# 76            Oman                  0.0
# 77         Belarus                  0.0
# 78            Peru                  0.0
#
# [79 rows x 2 columns]

# %%
lista_paises
# Out:
#    Billing_Country
# 0      Netherlands
# 1    United States
# 2            Japan
# 3            India
# 4            Italy
# ..             ...
# 74         Bahrain
# 75         Estonia
# 76            Oman
# 77         Belarus
# 78            Peru
#
# [79 rows x 1 columns]

# %%
plt.figure(figsize=(50,40))
# set width of bar
barWidth = 0.46

cant_TRF_por_pais = cant_TRF_por_pais.nlargest(30, columns= 'TRF')
# set height of bar
bars1 = cant_TRF_por_pais['TRF']
bars2 = op_closed_won.merge(cant_TRF_por_pais, how='right', left_on= 'Billing_Country', right_on = 'Billing_Country')['Quantity_Closed_Won']
#bars2 = op_closed_won['Quantity_Closed_Won']
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
 
# Make the plot
plt.bar(r1, bars1, color='orange', width=barWidth, edgecolor='white', label='TRF')
plt.bar(r2, bars2, color='green', width=barWidth, edgecolor='white', label='Closed Won')
 
# Add xticks on the middle of the group bars
#lt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(bars1))], lista_paises['Billing_Country'], rotation = 90, fontsize = 35)
plt.yticks(fontsize = 30)

#Tituo
plt.title("Oportunidades exitosas dado los 30 países con mayor TRF", fontsize = 60)

#Guardo figura
#DONDE SE GUARDA?
#plt.savefig('TRFvsClosedWon.png')

# Create legend & Show graphic
plt.legend(loc="upper center", fontsize = 50)
plt.show()

# %%
aprobacion_por_codigo
# Out:
#      Bureaucratic_Code  ...  Quantity_Pricing_Delivery_Approved
# 0  Bureaucratic_Code_0  ...                                  42
# 1  Bureaucratic_Code_1  ...                                 130
# 2  Bureaucratic_Code_2  ...                                 234
# 3  Bureaucratic_Code_3  ...                                   1
# 4  Bureaucratic_Code_4  ...                                9482
# 5  Bureaucratic_Code_5  ...                                   0
# 6  Bureaucratic_Code_6  ...                                   1
#
# [7 rows x 3 columns]

# %%
plt.figure(figsize=(20,20))
# set width of bar
barWidth = 0.46

# set height of bar
bars1 = aprobacion_por_codigo['Quantity_Need_Pricing_Delivery_Appr']
bars2 = aprobacion_por_codigo['Quantity_Pricing_Delivery_Approved']
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
 
# Make the plot
plt.bar(r1, bars1, color='red', width=barWidth, edgecolor='white', label='Necesitan aprobación especial')
plt.bar(r2, bars2, color='green', width=barWidth, edgecolor='white', label='Aprobación especial obtenida')
 
# Add xticks on the middle of the group bars
#lt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(bars1))], [0, 1, 2, 3, 4, 5, 6], rotation = 90, fontsize = 35)
plt.yticks(fontsize = 30)

#Etiquetas
plt.xlabel("Bureaucratic Code", fontsize= 35)

#Tituo
plt.title("Aprobación especial de precio y entrega para cada tipo de código burocrático", fontsize = 40)

#Guardo figura
#DONDE SE GUARDA?
#plt.savefig('TRFvsClosedWon.png')

# Create legend & Show graphic
plt.legend(loc="upper left", fontsize = 30)
plt.show()

# %%
closed_won_por_codigo
# Out:
#      Bureaucratic_Code  Quantity_Closed_Won
# 0  Bureaucratic_Code_0                   51
# 1  Bureaucratic_Code_1                  102
# 2  Bureaucratic_Code_2                  114
# 3  Bureaucratic_Code_3                    1
# 4  Bureaucratic_Code_4                 8253
# 5  Bureaucratic_Code_5                 1011
# 6  Bureaucratic_Code_6                    1

# %%
# Make a fake dataset:
height = closed_won_por_codigo['Quantity_Closed_Won']
bars = closed_won_por_codigo['Bureaucratic_Code']
y_pos = np.arange(len(bars))
 
# Create bars
plt.bar(y_pos, height, color = "pink")
 
# Create names on the x-axis
plt.xticks(y_pos, [0, 1, 2, 3, 4, 5, 6], rotation = 90)
plt.xlabel("Bureaucratic code")
plt.title("Oportunidades exitosas para cada código burocrático")

# Show graphic
plt.show()
